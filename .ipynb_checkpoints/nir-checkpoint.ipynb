# %% [markdown]
# Does the NIR spectrum look like an M dwarf?

# %%
#first get the python modules we need
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.convolution import convolve, Box1DKernel
from astropy.table import Table
import astropy.units as u
from astropy.modeling import models, fitting
from craftroom import resample
from scipy.interpolate import interp1d

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
#lines = [8498.02,8542.09,8662.14]
path = '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/' #note the / on the end

nirpath = path + 'NIR/'
sp = glob.glob(nirpath+'*.csv')
coadd = glob.glob(nirpath+'*merged.csv')
coadd
# Out:
# ['/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_merged.csv']

# %%
 w, f, e = np.loadtxt(coadd[0], unpack=True, skiprows=1)

# %%
plt.plot(w,f)
plt.plot(w,e)
plt.ylim(-1e-17, 1e-16)
# Out:
# (-1e-17, 1e-16)

# %%
#f= convolve(f,Box1DKernel(50))

# %%
plt.plot(w,f)

# %% [markdown]
# Does that look like the bands in the T1 spectrum?

# %%
# t1_p = Table.read('/home/david/work/muscles/SEDs/trappist-1/phoenix_repo/2560_5.0_0.0_0.0_phoenix_interpolated.txt', format='ascii')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-30b2092a257d> in <module>()
# ----> 1 t1_p = Table.read('/home/david/work/muscles/SEDs/trappist-1/phoenix_repo/2560_5.0_0.0_0.0_phoenix_interpolated.txt', format='ascii')
#
# /home/david/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      50     def __call__(self, *args, **kwargs):
#      51         cls = self._cls
# ---> 52         out = registry.read(cls, *args, **kwargs)
#      53
#      54         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /home/david/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/registry.py in read(cls, format, *args, **kwargs)
#     521
#     522         reader = get_reader(format, cls)
# --> 523         data = reader(*args, **kwargs)
#     524
# ...

# %%
wt, wf = t1_p['WAVELENGTH'], t1_p['FLUX']

# %%
tw, tf = resample.bintogrid(wt, wf, dx=1) 
mask = (tw > w[0]) & (tw < w[-1]) 
tw, tf = tw[mask], tf[mask]

# %%
plt.plot(tw, tf)

# %%
plt.figure(figsize=(9, 6))
plt.plot(tw, tf/1e30, label='TRAPPIST-1 model (arb. scaling)')
plt.plot(w[100:],f[100:], label='1144 X-shooter NIR')
plt.ylim(-1.9e-17, 0.52e-16)
plt.legend()
plt.xlabel('Wavelength (\AA)')
plt.ylabel('Flux (erg s$^{-1}$ cm$^{-2}$\AA$^{-1}$)')
plt.tight_layout()
plt.savefig('sdss1144_nir_quick_look.pdf')

# %% [markdown]
# Interesting. Play with scaling

# %%
mw, mf = np.loadtxt('da23027g774.dat', unpack=True)
mask = (mw > w[0]) & (mw < w[-1]) 
mw, mf = mw[mask], mf[mask]

# %%
plt.plot(tw, tf/1e30)
plt.plot(mw, mf)
plt.plot(w[100:],f[100:])
plt.ylim(-1e-17, 1e-16)

# %% [markdown]
# What about varible NIR?

# %%
for s in sp:
    if s != coadd[0]:
        wi, fi, ei = np.loadtxt(s, unpack=True, delimiter=',')
        fi = convolve(fi,Box1DKernel(50))
        plt.plot(wi, fi)  
    plt.ylim(-1e-17, 1e-16)

# %% [markdown]
# Yes? Have to see if it tracks day/night variation.

# %%
abs_dates = []
for s in sp:
    if s != coadd[0]:
        date = fits.getheader(s[:-3]+'fits')['MJD-OBS']
        abs_dates.append(date)
abs_args = np.argsort(abs_dates)

# %%
sp1 = []
for s in sp:
    if s != coadd[0]:
        sp1.append(s)

# %%
sp = np.array(sp1)[abs_args]
dates = np.array(abs_dates)[abs_args]

# %%
fluxes = [] #intergrated flux of first band
errors = []
for s in sp:
    wi, fi, ei = np.loadtxt(s, unpack=True, delimiter=',')
    mask = (wi > 10500) & (wi < 13500)
    fluxes.append(np.trapz(fi[mask], wi[mask]))
    errors.append((np.trapz(ei[mask]**2, wi[mask]))**0.5)
plt.errorbar(dates-dates[0], fluxes)
plt.xlim(0.9, 1.3)

# %% [markdown]
# Ok I can believe there's a trend

# %%
period = 4.226953752501198

tf = ((dates*24)/ period) % 1
args = np.argsort(tf)
tf = tf[args]
fluxes=np.array(fluxes)[args]
errors = np.array(errors)[args]
plt.errorbar(tf, fluxes, yerr=errors, marker='o', ls='none')

# %%
plt.plot(w,f)

# %%
from astropy.stats import sigma_clip

# %%
fbox= convolve(f,Box1DKernel(4))
ffilt = sigma_clip(fbox, 5)
plt.plot(w, ffilt)

# %%
fluxes = [] #intergrated flux of first band
errors = []
for s in sp:
    wi, fi, ei = np.loadtxt(s, unpack=True, delimiter=',')
   #mask = (wi > 10500) & (wi < 13500)
    fi= convolve(fi,Box1DKernel(4))
    fi = sigma_clip(fi, 5)
    ei = convolve(ei,Box1DKernel(4))/4**0.5
    fluxes.append(np.trapz(fi, wi))
    errors.append((np.trapz(ei**2, wi))**0.5)
#plt.errorbar(dates-dates[0], fluxes)
#plt.xlim(0.9, 1.3)


tf = ((dates*24)/ period) % 1
args = np.argsort(tf)
tf = tf[args]
fluxes=np.array(fluxes)[args]
errors = np.array(errors)[args]
plt.errorbar(tf, fluxes, yerr=errors, marker='o', ls='none')

# %%
#bandpasses
bps = glob.glob('2mass/*bandpass*')
bps

# %%
for bp in bps:
    wb, tb = np.loadtxt(bp, unpack=True)
    plt.plot(wb*10000, tb)
plt.plot(w, ffilt)

# %%
spt = sp[args]

# %%
bps = ['2mass/j_bandpass.txt', '2mass/h_bandpass.txt']
for bp in bps:
    fluxes = []
    errors= []
    wb, tb = np.loadtxt(bp, unpack=True)
    wb *= 10000
   # print(len(wb), len(tb))
    for s in spt:
        wi, fi, ei = np.loadtxt(s, unpack=True, delimiter=',')
        mask = (wi > wb[0]) & (wi < wb[-1])
        wi, fi, ei = wi[mask], fi[mask], ei[mask]
        fi= convolve(fi,Box1DKernel(4))
        fi = sigma_clip(fi, 5)
        ei = convolve(ei,Box1DKernel(4))/(4**0.5)
        #print(len(wb))
        wi, fi, ei = resample.bintogrid(wi, fi, unc=ei, newx=wb)
      #  print(len(wb))
        #fi = interp1d(wi, fi, fill_value='extrapolate')(wb)
        #ei = interp1d(wi, ei, fill_value='extrapolate')(wb)
        #print(len(wb), len(tb))
        tbi = interp1d(wb, tb, fill_value='extrapolate')(wi)
        fi *= tbi
        #ei *= tbi
        fluxes.append(np.trapz(fi, wi))
        errors.append((np.trapz(ei**2, wi))**0.5)
    plt.errorbar(tf, fluxes/np.median(fluxes), yerr=errors/np.median(fluxes), marker='o', ls='none')
#plt.ylim(0, 3)

# %% [markdown]
# 20210829 making coadded NIR spectrum

# %%
mddvs = Table.read('dv_lists/bd_dvs.ecsv')
mdt, mdv, mde = np.array(mddvs['MJD'])[4:], np.array(mddvs['VELOCITY'])[4:], np.array(mddvs['ERROR'])[4:]

# %%
spord = ['/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_0.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_1.csv',
         '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_2.csv',
         '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_3.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_4.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_5.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_6.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_7.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_8.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_9.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_10.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_11.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_12.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_13.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_14.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_15.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_16.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_17.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_18.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_19.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_20.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_21.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_22.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_23.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_24.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_25.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_26.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_27.csv',
       '/home/david/work/1144_lt/spectra/nicola_2/WDJ114404.76+052951.77/NIR/WDJ114404.76+052951.77_SCI_SLIT_FLUX_MERGE1D_NIR_28.csv']

# %%
import astropy.constants as const
from scipy.interpolate import interp1d

def spectra_adder(f_array, e_array):
    """
    Returns a variance-weighted coadd with standard error of the weighted mean (variance weights, scale corrected).
    f_array and e_arrays are collections of flux and error arrays, which should have the same lenth and wavelength scale
    """
    weights = 1 / (e_array**2)
    flux = np.average(f_array, axis =0, weights = weights)
    var = 1 / np.sum(weights, axis=0)
    rcs = np.sum((((flux - f_array)**2) * weights), axis=0) / (len(f_array)-1) #reduced chi-squared
    error = (var * rcs)**0.5 
    return flux, error#var**0.5

f_full = []
e_full = []

for i, s in enumerate(spord):
   # print(s)
    w, f, e = np.loadtxt(s, unpack=True, delimiter=',')
    mask = (w > 3300)
    w, f, e = w[mask], f[mask], e[mask]
    dv = mdv[i]
   # print(dv)
    shift = 1+(dv*1e3/const.c.value)
    if i == 0:
        w_full = w/shift
        f_full.append(f)
        e_full.append(e)
    else:
        f_full.append(interp1d(w/shift, f, fill_value='extrapolate')(w_full))
        e_full.append(interp1d(w/shift, e, fill_value='extrapolate')(w_full))

f_new, e_new = spectra_adder(np.array(f_full), np.array(e_full))
plt.step(w_full, f_new, where='mid')
plt.step(w_full, e_new, where='mid')
plt.xlim(3920, 3940)
plt.ylim(5e-16, 6e-16)
plt.show()
plt.plot(w_full, f_new/e_new)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-115a2c93a258> in <module>()
#      22     mask = (w > 3300)
#      23     w, f, e = w[mask], f[mask], e[mask]
# ---> 24     dv = mdv[i]
#      25    # print(dv)
#      26     shift = 1+(dv*1e3/const.c.value)
#
# IndexError: index 22 is out of bounds for axis 0 with size 22
